# %%
import pandas as pd
import numpy as np

# %%
dftransact = pd.read_csv("transactions.csv")
dftrain = pd.read_csv('train_accounts.csv')
dftransact.shape
# Out:
# (874985, 6)

# %%
dict_lookup = dict(zip(dftrain['account'], dftrain['flag']))

# %%
df1 = pd.read_csv('transactionsnew.csv')
df1.drop(df1.index[(df1["value"] == 0)],axis=0,inplace=True)

df2  = pd.read_csv('transactionsnew.csv')
df2.drop(df2.index[(df2["value"] != 0)],axis = 0,inplace = True)
print(df2.shape)
print(df1.shape)
# for i in df1.values:
#   if i[3] == 0:
#     df1.drop(i)
# Out:
# (611267, 7)
# (263718, 7)

# %%
for i in df1.values:
  if i[5] == 0:
    print(i)
# Out:
# ['b32708' 'a26364' '06-08-2020 07:41' 1.30917e+17 21000.0 0.0 0]
# ['b32708' 'a26364' '09-08-2020 07:40' 1.27951e+17 21000.0 0.0 0]
# ['b32708' 'a26364' '12-08-2020 07:49' 1.35561e+17 21000.0 0.0 0]
# ['b32708' 'a26364' '14-08-2020 07:39' 1.11539e+17 21000.0 0.0 0]
# ['b32708' 'a26364' '16-08-2020 07:35' 1.03318e+17 21000.0 0.0 0]
# ['b32708' 'a26364' '18-08-2020 07:48' 1.02616e+17 21000.0 0.0 0]
# ['b32708' 'a26364' '20-08-2020 07:58' 1.08776e+17 21000.0 0.0 0]
# ['b32708' 'a26364' '22-08-2020 07:36' 1.04598e+17 60000.0 0.0 0]
# ['b32708' 'a26364' '25-08-2020 07:33' 1.29821e+17 60000.0 0.0 0]
# ['b32708' 'a26364' '28-08-2020 07:50' 1.27703e+17 60000.0 0.0 0]
# ['b32708' 'a26364' '31-08-2020 07:53' 1.48003e+17 60000.0 0.0 0]
# ['b32708' 'a26364' '02-09-2020 08:11' 1.35194e+17 60000.0 0.0 0]
# ['b32708' 'a26364' '03-09-2020 08:14' 1.05231e+17 60000.0 0.0 0]
# ['b32708' 'a26364' '05-09-2020 07:49' 1.56464e+17 60000.0 0.0 0]
# ...
