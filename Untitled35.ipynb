# %% [markdown]
# # MODEL 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_data,train_labels) , (test_data, test_labels) = fashion_mnist.load_data()

# %%
print(train_labels[0])
# Out:
# 9

# %%
plt.imshow(train_data[0])

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_data = train_data/255.0
train_labels = train_labels/255.0

# %%
tf.random.set_seed(42)

# Create the model
model = tf.keras.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)), # input layer (we had to reshape 28x28 to 784)
  tf.keras.layers.Dense(128, activation="relu"),
  # tf.keras.layers.Dense(5, activation="relu"),
  # tf.keras.layers.Dense(5, activation="relu"),
  # tf.keras.layers.Dense(5, activation="relu"),
  # tf.keras.layers.Dense(4, activation="relu"),
  # tf.keras.layers.Dense(5, activation="relu"),
  tf.keras.layers.Dense(10, activation="softmax") # output shape is 10, activation is softmax
])

# Compile the model
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                 optimizer=tf.keras.optimizers.Adam(), # ideal learning rate (same as default)
                 metrics=["accuracy"])

# Fit the model
history = model.fit(train_data,
                       train_labels,
                       epochs=5,
                       validation_data=(test_data, test_labels))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0034 - accuracy: 0.1000 - val_loss: 13012.4463 - val_accuracy: 0.1000
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.3175e-06 - accuracy: 0.1000 - val_loss: 15250.1182 - val_accuracy: 0.1000
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 3.5370e-07 - accuracy: 0.1000 - val_loss: 17048.7031 - val_accuracy: 0.1000
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.1538e-07 - accuracy: 0.1000 - val_loss: 18566.0059 - val_accuracy: 0.1000
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 4.3538e-08 - accuracy: 0.1000 - val_loss: 19902.3867 - val_accuracy: 0.1000

# %%
# ======================================================================
# There are 5 questions in this exam with increasing difficulty from 1-5.
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score significantly
# less than your Category 5 question.
#
# Don't use lambda layers in your model.
# You do not need them to solve the question.
# Lambda layers are not supported by the grading infrastructure.
#
# You must use the Submit and Test button to submit your model
# at least once in this category before you finally submit your exam,
# otherwise you will score zero for this category.
# ======================================================================
#
# NLP QUESTION
#
# Build and train a classifier for the sarcasm dataset.
# The classifier should have a final layer with 1 neuron activated by sigmoid as shown.
# It will be tested against a number of sentences that the network hasn't previously seen
# and you will be scored on whether sarcasm was correctly detected in those sentences.

import json
import tensorflow as tf
import numpy as np
import urllib
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


def solution_model():
    url = 'https://storage.googleapis.com/download.tensorflow.org/data/sarcasm.json'
    urllib.request.urlretrieve(url, 'sarcasm.json')

    # DO NOT CHANGE THIS CODE OR THE TESTS MAY NOT WORK
    vocab_size = 1000
    embedding_dim = 16
    max_length = 120
    trunc_type='post'
    padding_type='post'
    oov_tok = "<OOV>"
    training_size = 20000

    sentences = []
    labels = []
    # YOUR CODE HERE


    model = tf.keras.Sequential([
    # YOUR CODE HERE. KEEP THIS OUTPUT LAYER INTACT OR TESTS MAY FAIL
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile()
    return model


# Note that you'll need to save your model as a .h5 like this.
# When you press the Submit and Test button, your saved .h5 model will
# be sent to the testing infrastructure for scoring
# and the score will be returned to you.
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-76371da4fbd7> in <cell line: 60>()
#      60 if __name__ == '__main__':
#      61     model = solution_model()
# ---> 62     model.save("mymodel.h5")
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in _assert_weights_created(self)
#    3538             # Also make sure to exclude Model class itself which has build()
#    3539             # defined.
# -> 3540             raise ValueError(
#    3541                 f"Weights for model '{self.name}' have not yet been "
#    3542                 "created. "
#
# ValueError: Weights for model 'sequential_19' have not yet been created. Weights are created when the model is first called on inputs or `build()` is called with an `input_shape`.

# %%
import json
import tensorflow as tf
import numpy as np
import urllib
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

url = 'https://storage.googleapis.com/download.tensorflow.org/data/sarcasm.json'
urllib.request.urlretrieve(url, 'sarcasm.json')

# DO NOT CHANGE THIS CODE OR THE TESTS MAY NOT WORK
vocab_size = 1000
embedding_dim = 16
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000

sentences = []
labels = []

# %%
df = pd.DataFrame.from_dict(pd.read_json("/content/sarcasm.json"), orient='columns')
# df2 = json_normalize(dict['technologies'])
x = df["headline"]
y = df["is_sarcastic"]

# %%
df.is_sarcastic.value_counts()
# Out:
# 0    14985
# 1    11724
# Name: is_sarcastic, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# Use train_test_split to split training data into training and validation sets
train_sentences, val_sentences, train_labels, val_labels = train_test_split(df["headline"].to_numpy(),
                                                                            df["is_sarcastic"].to_numpy(),
                                                                            test_size=0.1, # dedicate 10% of samples to validation set
                                                                            random_state=42) # random state for reproducibility

# %%
from tensorflow.keras.layers import TextVectorization # after TensorFlow 2.6

text_vectorizer = TextVectorization(max_tokens=vocab_size, # how many words in the vocabulary (all of the different words in your text)
                                    standardize="lower_and_strip_punctuation", # how to process text
                                    split="whitespace", # how to split tokens
                                    ngrams=None, # create groups of n-words?
                                    output_mode="int", # how to map tokens to numbers
                                    output_sequence_length=max_length,
                                    pad_to_max_tokens = True) # how long should the output sequence of tokens be?
                                    # pad_to_max_tokens=True) # Not valid if using max_tokens=None

# %%
text_vectorizer.adapt(train_sentences)

# %%
text_vectorizer.get_vocabulary()[:5]
# Out:
# ['', '[UNK]', 'to', 'of', 'the']

# %%
from tensorflow.keras import layers

embedding = layers.Embedding(input_dim=vocab_size, # set input shape
                             output_dim=16, # set size of embedding vector
                             embeddings_initializer="uniform", # default, intialize randomly
                             input_length=max_length, # how long is each input
                             name="embedding_1")

# %%
tf.random.set_seed(42)
from tensorflow.keras import layers

tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(train_sentences)

# %%
# Pad the sequences
max_length = max([len(seq) for seq in sequences])
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')

# Define the model architecture
vocabulary_size = len(word_index) + 1
embedding_dim = 100
model = tf.keras.Sequential()
model.add(layers.Embedding(input_dim=vocab_size, # set input shape
                             output_dim=16, # set size of embedding vector
                             embeddings_initializer="uniform", # default, intialize randomly
                             input_length=max_length, # how long is each input
                             name="embedding_1"))
model.add(layers.LSTM(100))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# %%
model_history = model.fit(padded_sequences,
                              train_labels,
                              epochs=10,
                              validation_data=(val_sentences, val_labels),
                              callbacks=[tf.keras.callbacks.ModelCheckpoint("/content/chkpt",
                                                                            save_best_only = True,
                                                                            name = model.name)])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-663eccc9ced7> in <cell line: 1>()
# ----> 1 model_history = model.fit(padded_sequences,
#       2                               train_labels,
#       3                               epochs=10,
#       4                               validation_data=(val_sentences, val_labels),
#       5                               callbacks=[tf.keras.callbacks.ModelCheckpoint("/content/chkpt",
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/data_adapter.py in _check_data_cardinality(data)
#    1850             )
#    1851         msg += "Make sure all arrays contain the same number of samples."
# -> 1852         raise ValueError(msg)
#    1853
#    1854
#
# ValueError: Data cardinality is ambiguous:
#   x sizes: 24038
#   y sizes: 60000
# Make sure all arrays contain the same number of samples.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Define the dataset
sentences = ["I love sarcasm", "This is not sarcasm", "What a great day!", "Can't wait for Monday..."]
labels = [1, 0, 0, 1]

# Tokenize the sentences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df["headline"])
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(sentences)

# Pad the sequences
max_length = max([len(seq) for seq in sequences])
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')

# Define the model architecture
vocabulary_size = len(word_index) + 1
embedding_dim = 100
model = Sequential()
model.add(Embedding(vocabulary_size, embedding_dim, input_length=max_length))
model.add(LSTM(100))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Split the data into training and testing sets
split_index = int(len(padded_sequences) * 0.8)
X_train = padded_sequences[:split_index]
y_train = df["is_sarcastic"][:split_index]
X_test = padded_sequences[split_index:]
y_test = df["is_sarcastic"][split_index:]

# Train the model
model.fit(X_train, y_train, batch_size=32, epochs=10)


# Print the model's performance
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.6917 - accuracy: 0.6667
# Epoch 2/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6833 - accuracy: 0.6667
# Epoch 3/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6747 - accuracy: 1.0000
# Epoch 4/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6658 - accuracy: 1.0000
# Epoch 5/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6563 - accuracy: 1.0000
# Epoch 6/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6461 - accuracy: 1.0000
# Epoch 7/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6348 - accuracy: 1.0000
# Epoch 8/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6225 - accuracy: 1.0000
# Epoch 9/10
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6088 - accuracy: 1.0000
# Epoch 10/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5936 - accuracy: 1.0000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-3e458649836e> in <cell line: 43>()
#      41
#      42 # Evaluate the model
# ---> 43 loss, accuracy = model.evaluate(X_test, y_test)
#      44
#      45 # Print the model's performance
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/data_adapter.py in _check_data_cardinality(data)
#    1850             )
#    1851         msg += "Make sure all arrays contain the same number of samples."
# -> 1852         raise ValueError(msg)
#    1853
#    1854
#
# ValueError: Data cardinality is ambiguous:
#   x sizes: 1
#   y sizes: 26706
# Make sure all arrays contain the same number of samples.

# %%
# Out:
# Streaming output truncated to the last 5000 lines.
# look: what it's like to race canoes in ny's hudson river
# big coal funded this prominent climate change denier, docs reveal
# where did the freedom go? fight for the accessible information continues
# shared memory of children's television show leads to sex
# the tr*mp effect: transgender folks' mental health post-election
# comedian shows how easy it is to get a medical marijuana card in california
# fresca quietly takes control of 18-34 demographic in daring overnight raid
# man who didn't get joke acts like he did
# nervous voter totally blanks on american values while looking at ballot
# advisors tell trump, cruz to stick to just attacking all women in general
# monster got tina
# goldfish dying to be petted just once
# lettuce sentenced to slow, painful death in vegetable crisper drawer
# panhandler demands explanation for failure to provide quarter
# vacation to israel canceled due to history of israel
# obamacare case to be turned against government on emissions rule
# the tragic death of alejandro nieto and san francisco's gentrification
# olympic skier ashley caldwell's snooze button habit is so relatable
# frantic john kerry looks on as teresa slowly lowered into kim jong-un's electric eel tank
# hot-rod-lincoln-driving son may have contributed to father's alcoholism
# yes, men are still harassing people on the street. no, it's still not okay.
# floyd mayweather jr. stripped of title from manny pacquiao fight
# man on horse hates city
# the iconic blue ikea bag is getting a makeover
# poll: majority of americans ready to give up on u.s. if someone else goes first
# brilliant, innovative ceo just wrote words 'social media' on whiteboard and underlined it
# donald trump will not get his son-in-law's newspaper's endorsement
# greece votes in its second election of 2015
# 6 things you need to know about drowsy driving
# report: some shithead out there makes so much more money than you
# 3 attacks in 3 months put spotlight on terrorism in the u.k.
# trump holds strategy meeting with campaign's top militia leaders ahead of election day
# avoiding auto repair scams
# 7-eleven shareholders approve sale of busch light six-pack
# man thinks he managed to masturbate without waking roommate
# un/opcw report blames syria government, islamic state for chemical attacks
# kim jong-un's absence leaves north korean government officials no one to agree with
# dog born with odds stacked against her found just the parents she needed
# american dream week a smashing, mostly uninvestigated success
# complete idiot forgot to shave area between mouth and nose
# retreating clinton campaign torches iowa town to slow advance of sanders volunteers
# don't nobody wanna hear area man run his mouth
# 48 syrian civilians massacred during claire danes' emmy award acceptance speech
# readin' researchin' writin' and the tools to make it happen
# report: uttering phrase 'easy does it' prevents 78% of drywall damage while moving furniture
# ted cruz blasts new york times for keeping book off bestseller list
# voting underway in myanmar's first free election in 25 years
# ice cube thrown into sink flies up side like skateboarder shredding half-pipe
# fisherman's worst nightmare comes true
# new bailiff tired of hearing how old bailiff did things
# breaking: 'the onion' in kill range of boston bomber suspect
# seaworld crowd applauds for dolphin playfully spraying blood from blowhole
# zimbabwe's youth defy blackout to organize protests on social media
# emma gonzalez: 'one of the biggest threats' to teens today 'is being shot'
# hackers breached u.s. election agency after vote, according to security firm
# what you should buy your 'basic' friend, according to pinterest
# what's in your mailbox? tips on what to do when uncle sam comes knocking
# paul ryan is more of a con man than ever
# pentagon to withhold budget figures out of respect for american families
# pope francis wearing sweater vestments he got for christmas
# american politics in moral free-fall
# america's best 20 hikes
# reparations and obama
# israeli ban targeting boycott supporters raises alarm abroad
# gourmet gifts for the foodie 2014

# %%
from tensorflow.keras import layers
inputs = layers.Input(shape=(1,), dtype="string")
train_data_final
x = text_vectorizer(inputs)
x = embedding(x)
model_5 = tf.keras.Sequential([

])
x = layers.Conv1D(filters=32, kernel_size=5, activation="relu")(x)
x = layers.GlobalMaxPool1D()(x)
# x = layers.Dense(64, activation="relu")(x) # optional dense layer
outputs = layers.Dense(1, activation="sigmoid")(x)
model_5 = tf.keras.Model(inputs, outputs, name="model_5_Conv1D")

# Compile Conv1D model
model_5.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Define the dataset
sentences = ["I love sarcasm", "This is not sarcasm", "What a great day!", "Can't wait for Monday..."]
labels = [1, 0, 0, 1]

# Tokenize the sentences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(sentences)

# Pad the sequences
max_length = max([len(seq) for seq in sequences])
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')

# Define the model architecture
vocabulary_size = len(word_index) + 1
embedding_dim = 100
model = Sequential()
model.add(Embedding(vocabulary_size, embedding_dim, input_length=max_length))
model.add(LSTM(100))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(padded_sequences, labels, batch_size=32, epochs=10)

# Save the model
model.save("sarcasm_classifier_model.h5")
print("Model saved.")

# %%
model_5_history = model_5.fit(train_sentences,
                              train_labels,
                              epochs=10,
                              validation_data=(val_sentences, val_labels),
                              callbacks=[tf.keras.callbacks.ModelCheckpoint("/content/chkpt",
                                                                            save_best_only = True,
                                                                            name = model.name)])
# Out:
# Epoch 1/10
# 752/752 [==============================] - ETA: 0s - loss: 0.4840 - accuracy: 0.7593
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 752/752 [==============================] - 21s 19ms/step - loss: 0.4840 - accuracy: 0.7593 - val_loss: 0.4091 - val_accuracy: 0.8147
# Epoch 2/10
# 752/752 [==============================] - ETA: 0s - loss: 0.3735 - accuracy: 0.8343
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 752/752 [==============================] - 5s 7ms/step - loss: 0.3735 - accuracy: 0.8343 - val_loss: 0.3938 - val_accuracy: 0.8214
# Epoch 3/10
# 752/752 [==============================] - 5s 6ms/step - loss: 0.3438 - accuracy: 0.8482 - val_loss: 0.3939 - val_accuracy: 0.8244
# Epoch 4/10
# 752/752 [==============================] - ETA: 0s - loss: 0.3214 - accuracy: 0.8607
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 752/752 [==============================] - 5s 7ms/step - loss: 0.3214 - accuracy: 0.8607 - val_loss: 0.3876 - val_accuracy: 0.8259
# Epoch 5/10
# 752/752 [==============================] - 4s 5ms/step - loss: 0.3008 - accuracy: 0.8708 - val_loss: 0.3948 - val_accuracy: 0.8285
# Epoch 6/10
# 752/752 [==============================] - 6s 7ms/step - loss: 0.2821 - accuracy: 0.8814 - val_loss: 0.4002 - val_accuracy: 0.8300
# Epoch 7/10
# 752/752 [==============================] - 4s 5ms/step - loss: 0.2649 - accuracy: 0.8897 - val_loss: 0.4098 - val_accuracy: 0.8248
# Epoch 8/10
# 752/752 [==============================] - 5s 6ms/step - loss: 0.2472 - accuracy: 0.8980 - val_loss: 0.4200 - val_accuracy: 0.8240
# Epoch 9/10
# 752/752 [==============================] - 5s 6ms/step - loss: 0.2310 - accuracy: 0.9057 - val_loss: 0.4364 - val_accuracy: 0.8199
# Epoch 10/10
# 752/752 [==============================] - 4s 5ms/step - loss: 0.2163 - accuracy: 0.9139 - val_loss: 0.4528 - val_accuracy: 0.8169

# %%
model_5.save("mymodel5.h5")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-61-537dad1ec06a> in <cell line: 1>()
# ----> 1 model_5.save("mymodel5.h5")
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/saving/legacy/hdf5_format.py in _legacy_weights(layer)
#    1100     weights = layer.trainable_weights + layer.non_trainable_weights
#    1101     if any(not isinstance(w, tf.Variable) for w in weights):
# -> 1102         raise NotImplementedError(
#    1103             "Save or restore weights that is not an instance of `tf.Variable` "
#    1104             "is not supported in h5, use `save_format='tf'` instead. Received "
#
# NotImplementedError: Save or restore weights that is not an instance of `tf.Variable` is not supported in h5, use `save_format='tf'` instead. Received a model or layer TextVectorization with weights [<keras.layers.preprocessing.index_lookup.VocabWeightHandler object at 0x7f5d78648580>]

# %%
MODEL

# %% [markdown]
# ## MODEL 3

# %%
# ======================================================================
# There are 5 questions in this exam with increasing difficulty from 1-5.
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score significantly
# less than your Category 5 question.
#
# Don't use lambda layers in your model.
# You do not need them to solve the question.
# Lambda layers are not supported by the grading infrastructure.
#
# You must use the Submit and Test button to submit your model
# at least once in this category before you finally submit your exam,
# otherwise you will score zero for this category.
# ==============================================================================
#
# BASIC DATASETS QUESTION
#
# Create a classifier for the German Traffic Signs dataset that classifies
# images of traffic signs into 43 classes.
# ==============================================================================
#
# ABOUT THE DATASET
#
# The dataset contains traffic sign boards from the streets captured into
# image files. There are 43 unique classes in total. The images are of shape
# (30,30,3).
# ==============================================================================
#
# INSTRUCTIONS
#
# We have already divided the data for training and validation.
#
# Complete the code in following functions:
# 1. preprocess()
# 2. solution_model()
#
# Your code will fail to be graded if the following criteria are not met:
# 1. The input shape of your model must be (30,30,3), because the testing
#    infrastructure expects inputs according to this specification.
# 2. The last layer of your model must be a Dense layer with 43 neurons
#    activated by softmax since this dataset has 43 classes.
#
# HINT: Your neural network must have a validation accuracy of approximately
# 0.95 or above on the normalized validation dataset for top marks.



# This function downloads and extracts the dataset to the directory that
# contains this file.
# DO NOT CHANGE THIS CODE
# (unless you need to change https to http)

# This function loads the data, normalizes and resizes the images, splits it into
# train and validation sets, defines the model, compiles it and finally
# trains the model. The trained model is returned from this function.

# COMPLETE THE CODE IN THIS FUNCTION.


# Note that you'll need to save your model as a .h5 like this.
# When you press the Submit and Test button, your saved .h5 model will
# be sent to the testing infrastructure for scoring
# and the score will be returned to you.
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")

# %%
import urllib
import zipfile

import tensorflow as tf

# %%
def download_and_extract_data():
    url = 'https://storage.googleapis.com/download.tensorflow.org/data/certificate/germantrafficsigns.zip'
    urllib.request.urlretrieve(url, 'germantrafficsigns.zip')
    with zipfile.ZipFile('germantrafficsigns.zip', 'r') as zip_ref:
        zip_ref.extractall()

# %%
# COMPLETE THE CODE IN THIS FUNCTION
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def preprocess(image, label):
    # NORMALIZE YOUR IMAGES HERE (HINT: Rescale by 1/.255)
    image = image/.255
    return image, label

# %%
from tensorflow.keras import layers
def solution_model():
    # Downloads and extracts the dataset to the directory that
    # contains this file.
    download_and_extract_data()

    BATCH_SIZE = 32
    IMG_SIZE = 30

    # The following code reads the training and validation data from their
    # respective directories, resizes them into the specified image size
    # and splits them into batches. You must fill in the image_size
    # argument for both training and validation data.
    # HINT: Image size is a tuple
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        directory='train/',
        label_mode='categorical',
        image_size= (30,30) # YOUR CODE HERE
        , batch_size = BATCH_SIZE)

    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
        directory='validation/',
        label_mode='categorical',
        image_size=  (30,30)# YOUR CODE HERE
        , batch_size = BATCH_SIZE)

    # Normalizes train and validation datasets using the
    # preprocess() function.
    # Also makes other calls, as evident from the code, to prepare them for
    # training.
    # Do not batch or resize the images in the dataset here since it's already
    # been done previously.

    train_ds = train_ds.map(
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE).prefetch(
        tf.data.experimental.AUTOTUNE)
    val_ds = val_ds.map(
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)

    # Code to define the model
    model = tf.keras.models.Sequential([
        # ADD LAYERS OF THE MODEL HERE
        layers.Conv2D(5, 5, activation='relu', input_shape=(30, 30, 3)),
        # layers.MaxPool2D(pool_size=2), # reduce number of features by half
        layers.Conv2D(5, 5, activation='relu'),
        # layers.Conv2D(10, 3, activation='relu'),
        layers.MaxPool2D(),
        layers.Conv2D(5, 5, activation='relu'),
        # layers.Conv2D(10, 3, activation='relu'),
        layers.MaxPool2D(),
        layers.Flatten(),
        # If you don't adhere to the instructions in the following comments,
        # tests will fail to grade your model:
        # The input layer of your model must have an input shape of
        # (30,30,3).
        # Make sure your last layer has 43 neurons activated by softmax.
        tf.keras.layers.Dense(43, activation=tf.nn.softmax)
    ])

    # Code to compile and train the model
    model.compile(loss='binary_crossentropy',
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

    model.fit(train_ds,
                        epochs=5,
                        steps_per_epoch=len(train_ds),
                        validation_data=val_ds,
                        validation_steps=len(val_ds))

    return model

# %%
model = solution_model()
# Out:
# Found 31367 files belonging to 43 classes.
# Found 7842 files belonging to 43 classes.
# Epoch 1/5
# 981/981 [==============================] - 13s 11ms/step - loss: 0.1281 - accuracy: 0.0512 - val_loss: 0.1042 - val_accuracy: 0.0545
# Epoch 2/5
# 981/981 [==============================] - 10s 10ms/step - loss: 0.1030 - accuracy: 0.0719 - val_loss: 0.1001 - val_accuracy: 0.1125
# Epoch 3/5
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0857 - accuracy: 0.2565 - val_loss: 0.0671 - val_accuracy: 0.4181
# Epoch 4/5
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0552 - accuracy: 0.5388 - val_loss: 0.0498 - val_accuracy: 0.5947
# Epoch 5/5
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0370 - accuracy: 0.7195 - val_loss: 0.0284 - val_accuracy: 0.8002

# %%
model.save("bestmodel.h5")

# %%
# ======================================================================
# There are 5 questions in this exam with increasing difficulty from 1-5.
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score significantly
# less than your Category 5 question.
#
# Don't use lambda layers in your model.
# You do not need them to solve the question.
# Lambda layers are not supported by the grading infrastructure.
#
# You must use the Submit and Test button to submit your model
# at least once in this category before you finally submit your exam,
# otherwise you will score zero for this category.
# ==============================================================================
#
# BASIC DATASETS QUESTION
#
# Create a classifier for the German Traffic Signs dataset that classifies
# images of traffic signs into 43 classes.
# ==============================================================================
#
# ABOUT THE DATASET
#
# The dataset contains traffic sign boards from the streets captured into
# image files. There are 43 unique classes in total. The images are of shape
# (30,30,3).
# ==============================================================================
#
# INSTRUCTIONS
#
# We have already divided the data for training and validation.
#
# Complete the code in following functions:
# 1. preprocess()
# 2. solution_model()
#
# Your code will fail to be graded if the following criteria are not met:
# 1. The input shape of your model must be (30,30,3), because the testing
#    infrastructure expects inputs according to this specification.
# 2. The last layer of your model must be a Dense layer with 43 neurons
#    activated by softmax since this dataset has 43 classes.
#
# HINT: Your neural network must have a validation accuracy of approximately
# 0.95 or above on the normalized validation dataset for top marks.

import urllib
import zipfile

import tensorflow as tf

# This function downloads and extracts the dataset to the directory that
# contains this file.
# DO NOT CHANGE THIS CODE
# (unless you need to change https to http)
def download_and_extract_data():
    url = 'https://storage.googleapis.com/download.tensorflow.org/data/certificate/germantrafficsigns.zip'
    urllib.request.urlretrieve(url, 'germantrafficsigns.zip')
    with zipfile.ZipFile('germantrafficsigns.zip', 'r') as zip_ref:
        zip_ref.extractall()

# COMPLETE THE CODE IN THIS FUNCTION
def preprocess(image, label):
    # NORMALIZE YOUR IMAGES HERE (HINT: Rescale by 1/.255)
    image = image/.255
    return image, label



# This function loads the data, normalizes and resizes the images, splits it into
# train and validation sets, defines the model, compiles it and finally
# trains the model. The trained model is returned from this function.

# COMPLETE THE CODE IN THIS FUNCTION.
from tensorflow.keras import layers
from tensorflow.keras import layers
def solution_model():
    # Downloads and extracts the dataset to the directory that
    # contains this file.
    download_and_extract_data()

    BATCH_SIZE = 32
    IMG_SIZE = 30

    # The following code reads the training and validation data from their
    # respective directories, resizes them into the specified image size
    # and splits them into batches. You must fill in the image_size
    # argument for both training and validation data.
    # HINT: Image size is a tuple
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        directory='train/',
        label_mode='categorical',
        image_size= (30,30) # YOUR CODE HERE
        , batch_size = BATCH_SIZE)

    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
        directory='validation/',
        label_mode='categorical',
        image_size=  (30,30)# YOUR CODE HERE
        , batch_size = BATCH_SIZE)

    # Normalizes train and validation datasets using the
    # preprocess() function.
    # Also makes other calls, as evident from the code, to prepare them for
    # training.
    # Do not batch or resize the images in the dataset here since it's already
    # been done previously.

    train_ds = train_ds.map(
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE).prefetch(
        tf.data.experimental.AUTOTUNE)
    val_ds = val_ds.map(
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)

    # Code to define the model
    model = tf.keras.models.Sequential([
        # ADD LAYERS OF THE MODEL HERE
        layers.Conv2D(10, 5, activation='relu', input_shape=(30, 30, 3)),
        # layers.MaxPool2D(pool_size=2), # reduce number of features by half
        layers.Conv2D(10, 5, activation='relu'),
        # layers.Conv2D(10, 3, activation='relu'),
        layers.MaxPool2D(),
        layers.Conv2D(10, 5, activation='relu'),
        # layers.Conv2D(10, 3, activation='relu'),
        layers.MaxPool2D(),
        layers.Flatten(),
        # If you don't adhere to the instructions in the following comments,
        # tests will fail to grade your model:
        # The input layer of your model must have an input shape of
        # (30,30,3).
        # Make sure your last layer has 43 neurons activated by softmax.
        tf.keras.layers.Dense(43, activation=tf.nn.softmax)
    ])

    # Code to compile and train the model
    model.compile(loss='binary_crossentropy',
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

    model.fit(train_ds,
                        epochs=20,
                        steps_per_epoch=len(train_ds),
                        validation_data=val_ds,
                        validation_steps=len(val_ds))

    return model


# Note that you'll need to save your model as a .h5 like this.
# When you press the Submit and Test button, your saved .h5 model will
# be sent to the testing infrastructure for scoring
# and the score will be returned to you.
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Found 31367 files belonging to 43 classes.
# Found 7842 files belonging to 43 classes.
# Epoch 1/20
# 981/981 [==============================] - 12s 11ms/step - loss: 0.1210 - accuracy: 0.0579 - val_loss: 0.1053 - val_accuracy: 0.0631
# Epoch 2/20
# 981/981 [==============================] - 11s 11ms/step - loss: 0.1043 - accuracy: 0.0663 - val_loss: 0.1034 - val_accuracy: 0.0727
# Epoch 3/20
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0687 - accuracy: 0.4211 - val_loss: 0.0473 - val_accuracy: 0.6325
# Epoch 4/20
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0411 - accuracy: 0.6939 - val_loss: 0.0346 - val_accuracy: 0.7547
# Epoch 5/20
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0308 - accuracy: 0.7857 - val_loss: 0.0287 - val_accuracy: 0.8067
# Epoch 6/20
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0238 - accuracy: 0.8436 - val_loss: 0.0238 - val_accuracy: 0.8407
# Epoch 7/20
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0194 - accuracy: 0.8765 - val_loss: 0.0174 - val_accuracy: 0.8901
# Epoch 8/20
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0157 - accuracy: 0.8995 - val_loss: 0.0153 - val_accuracy: 0.9032
# Epoch 9/20
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0138 - accuracy: 0.9118 - val_loss: 0.0149 - val_accuracy: 0.9088
# Epoch 10/20
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0124 - accuracy: 0.9203 - val_loss: 0.0151 - val_accuracy: 0.9078
# Epoch 11/20
# 981/981 [==============================] - 12s 12ms/step - loss: 0.0109 - accuracy: 0.9302 - val_loss: 0.0196 - val_accuracy: 0.8818
# Epoch 12/20
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0103 - accuracy: 0.9345 - val_loss: 0.0129 - val_accuracy: 0.9311
# Epoch 13/20
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0102 - accuracy: 0.9351 - val_loss: 0.0135 - val_accuracy: 0.9245
# Epoch 14/20
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0092 - accuracy: 0.9408 - val_loss: 0.0112 - val_accuracy: 0.9404
# Epoch 15/20
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0089 - accuracy: 0.9434 - val_loss: 0.0129 - val_accuracy: 0.9280
# Epoch 16/20
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0084 - accuracy: 0.9455 - val_loss: 0.0119 - val_accuracy: 0.9297
# Epoch 17/20
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0084 - accuracy: 0.9470 - val_loss: 0.0128 - val_accuracy: 0.9341
# Epoch 18/20
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0081 - accuracy: 0.9492 - val_loss: 0.0100 - val_accuracy: 0.9466
# Epoch 19/20
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0078 - accuracy: 0.9513 - val_loss: 0.0105 - val_accuracy: 0.9427
# Epoch 20/20
# 981/981 [==============================] - 9s 10ms/step - loss: 0.0074 - accuracy: 0.9540 - val_loss: 0.0100 - val_accuracy: 0.9478

# %%
model.save("model_folder")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
