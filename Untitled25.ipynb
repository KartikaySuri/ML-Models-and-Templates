# %%
# !pip install ray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 MB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 53.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 KB 33.3 MB/s eta 0:00:00
# ...

# %%
import ray
ray.init(ignore_reinit_error=True)
# Out:
# 2023-01-17 14:17:54,414	INFO worker.py:1538 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.8.16', ray_version='2.2.0', ray_commit='b6af0887ee5f2e460202133791ad941a41f15beb', address_info={'node_ip_address': '172.28.0.2', 'raylet_ip_address': '172.28.0.2', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2023-01-17_14-17-51_258304_293/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2023-01-17_14-17-51_258304_293/sockets/raylet', 'webui_url': '', 'session_dir': '/tmp/ray/session_2023-01-17_14-17-51_258304_293', 'metrics_export_port': 52154, 'gcs_address': '172.28.0.2:42061', 'address': '172.28.0.2:42061', 'dashboard_agent_listen_port': 52365, 'node_id': '20eacf7a1d351ea111f996d43c16119c15803e274f0fa8d765e3c126'})

# %%
import time
print("timer started\n")
print("_____________________")
start = time.time()
