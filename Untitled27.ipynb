# %%
# !pip install streamlit -q
# !pip install air-quality-index
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting air-quality-index
#   Downloading air_quality_index-0.2.1-py2.py3-none-any.whl (4.2 kB)
# Collecting kml2geojson
#   Downloading kml2geojson-5.1.0-py3-none-any.whl (9.9 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from air-quality-index) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from air-quality-index) (2.25.1)
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 KB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->air-quality-index) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->air-quality-index) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->air-quality-index) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->air-quality-index) (2.10)
# Installing collected packages: click, kml2geojson, air-quality-index
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires click<8.0,>=5.1, but you have click 8.1.3 which is incompatible.
# Successfully installed air-quality-index-0.2.1 click-8.1.3 kml2geojson-5.1.0

# %%
# !pip install streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 81.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 70.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.4/238.4 KB 23.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.0/79.0 KB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 KB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 KB 5.3 MB/s eta 0:00:00
#   Building wheel for validators (setup.py) ... done

# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
import plotly.express as px

# %%
df =pd.read_csv("Real-Time_Traffic_Incident_Reports.csv")

# %%
df_utils=df.dropna(axis=0)
df_utils.reset_index(drop=True,inplace=True)
 
a=df_utils['Published Date'].str.split(" ")
b=[]
for i in range(0,len(a)):
 c=a[i][0]
 b.append(c)
 
d=df_utils['Status Date'].str.split(" ")
e=[]
for i in range(0,len(a)):
 f=d[i][0]
 e.append(f)
 
g=df_utils['Published Date'].str.split('/')
h=[]
for i in range(0,len(a)):
 f=g[i][2]
 h.append(f)
 
df_utils['pub_date']=b
df_utils['stat_date']=e
df_utils['pub_year']=h
 
df_utils[:5]
# Out:
#   Traffic Report ID                Published Date  Issue Reported  \
# 0                A1  06/13/2018 06:35:59 AM +0000   Crash Service
# 1                A2  06/13/2018 10:15:36 AM +0000  Traffic Hazard
# 2                A3  04/17/2020 09:25:03 PM +0000    Crash Urgent
# 3                A4  04/17/2020 09:40:52 PM +0000  Traffic Hazard
# 4                A5  04/17/2020 09:00:55 PM +0000    Crash Urgent
#
#                  Location   Latitude  Longitude  \
# 0  (30.283797,-97.741906)  30.283797 -97.741906
# 1  (30.339593,-97.700963)  30.339593 -97.700963
# 2  (30.329455,-97.638105)  30.329455 -97.638105
# 3  (30.202806,-97.760701)  30.202806 -97.760701
# 4  (30.184265,-97.687339)  30.184265 -97.687339
#
#                                        Address    Status  \
# 0                     W 21ST ST & GUADALUPE ST  ARCHIVED
# 1                     400-717 E ANDERSON LN EB  ARCHIVED
# 2  E US 290 HWY SVRD EB & EASTERN HEIGHTS BLVD  ARCHIVED
# 3                          5300-blk S Ih 35 Sb  ARCHIVED
# 4                    4500-4720 S Us 183 Hwy Sb  ARCHIVED
#
#                     Status Date    pub_date   stat_date  \
# 0  06/13/2018 09:00:03 AM +0000  06/13/2018  06/13/2018
# 1  06/13/2018 11:20:03 AM +0000  06/13/2018  06/13/2018
# 2  04/17/2020 09:55:03 PM +0000  04/17/2020  04/17/2020
# 3  04/17/2020 09:55:03 PM +0000  04/17/2020  04/17/2020
# 4  04/17/2020 11:30:04 PM +0000  04/17/2020  04/17/2020
#
#                  pub_year
# 0  2018 06:35:59 AM +0000
# 1  2018 10:15:36 AM +0000
# 2  2020 09:25:03 PM +0000
# 3  2020 09:40:52 PM +0000
# 4  2020 09:00:55 PM +0000

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px
df = pd.read_csv("Real-Time_Traffic_Incident_Reports.csv")
df_utils=df.dropna(axis=0)
df_utils.reset_index(drop=True,inplace=True)
a=df_utils['Published Date'].str.split(" ")
# for publish date
b=[]
for i in range(0,len(a)):
 c=a[i][0]
 b.append(c)
#for status date
d=df_utils['Status Date'].str.split(" ")
e=[]
for i in range(0,len(a)):
 f=d[i][0]
 e.append(f)
df_utils['pub_date']=b
df_utils['stat_date']=e
g=df_utils['pub_date'].str.split('/')
h=[]
for i in range(0,len(a)):
 f=g[i][2]
 h.append(f)
df_utils['pub_year']=h
st.header("Real-Time Dashboard")
chart_selector = st.sidebar.selectbox("Select the type of chart", ['Pie chart','Bar chart'])
col1, col2 = st.columns(2)
if chart_selector=='Pie chart':
  pie_chart = px.pie(df_utils, values='pub_year', names='Issue Reported')
  col1.plotly_chart(pie_chart,use_container_width = True)
else:
  bar_chart = px.histogram(df_utils, x="Issue Reported", color="pub_year")
  col2.plotly_chart(bar_chart,use_container_width = True)
# Out:
# Overwriting app.py

# %%
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to False.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.86.3.110:8501
#
# npx: installed 22 in 4.525s
# your url is: https://long-grapes-study-34-86-3-110.loca.lt
# /usr/local/lib/python3.8/dist-packages/streamlit/runtime/scriptrunner/script_runner.py:565: DtypeWarning: Columns (0,1,2,3,6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code, module.__dict__)
# /content/app.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_utils['pub_date']=b
# /content/app.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_utils['stat_date']=e
# /content/app.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_utils['pub_year']=h
# /usr/local/lib/python3.8/dist-packages/streamlit/runtime/scriptrunner/script_runner.py:565: DtypeWarning:
#
# Columns (0,1,2,3,6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /content/app.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /content/app.py:21: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /content/app.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   Stopping...
# ^C
