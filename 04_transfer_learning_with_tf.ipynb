# %%
# transfer learning with tensorflow introduction mainly for feature extraction

# %%
# preparing the data and creating and loading the data generators

from tensorflow.keras.preprocessing.image import Imageda
